# %%
import context
from IPython.display import Image
import matplotlib.pyplot as plt
# make the plots happen inline
# %matplotlib inline  
# import the numpy array handling library
import numpy as np
# import the advection code from the numlabs directory
import numlabs.lab10.advection_funs2 as afs
import numlabs.lab10.advection_funs3 as afs2
import numlabs.lab10.advection_funs21 as afs3
# Out:
# ******************************
# context imported. Front of path:
# /Users/jvalenti/numeric_2022
# back of path: /Users/jvalenti/.local/lib/python3.10/site-packages
# ******************************
#
# through /Users/jvalenti/numeric_2022/notebooks/lab10/context.py

# %% [markdown]
# ### Problem One ###
#
# Using the Bott Scheme, modify initialize in *advection_funs.py* to solve the following advection problem: The wind is moving along the x-axis with speed u=20 m/s. The initial distribution curve is 50 km in width. Use your program to approximate the curve during 24 hours.

# %%
fig,axs=plt.subplots(figsize=[15,5])
afs.advection3(1250, 4,axs,lab_example=False)
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [3.13973627e-12, 3.19485138e-12, 3.25119418e-12, ...,
#         3.25119418e-12, 3.30879211e-12, 3.36767351e-12],
#        [3.11817063e-12, 3.17280550e-12, 3.22865725e-12, ...,
#         3.22865725e-12, 3.28575309e-12, 3.34412114e-12],
#        [3.09679286e-12, 3.15095172e-12, 3.20631673e-12, ...,
#         3.20631673e-12, 3.26291491e-12, 3.32077411e-12]])

# %% [markdown]
# a\) Run your program for different orders of approximating polynomials
# (up to 4). Compare the accuracy of approximation for different orders.
# Do you see better results with increasing order? Is this true for all
# orders from 0 to 4? Is there any particularity to odd and even order
# polynomials? What if you decrease the Courant number (value in front of dx/u for dt calculation)?
#
# -The best approximation seems to be given by the third order approximation, the second order would be better if it did not increased the concentration in time in the first hours of the run. A higher order does not always mean a better result, the results for orders 4 are worse than order 3.
#
# I don't see any particular difference between odd and even orders.

# %%
fig,axs=plt.subplots(5,1,figsize=[15,20])
afs.advection3(1250, 0,axs[0],lab_example=False) 
afs.advection3(1250, 1,axs[1],lab_example=False)
afs.advection3(1250, 2,axs[2],lab_example=False)
afs.advection3(1250, 3,axs[3],lab_example=False)
afs.advection3(1250, 4,axs[4],lab_example=False)
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [3.13973627e-12, 3.19485138e-12, 3.25119418e-12, ...,
#         3.25119418e-12, 3.30879211e-12, 3.36767351e-12],
#        [3.11817063e-12, 3.17280550e-12, 3.22865725e-12, ...,
#         3.22865725e-12, 3.28575309e-12, 3.34412114e-12],
#        [3.09679286e-12, 3.15095172e-12, 3.20631673e-12, ...,
#         3.20631673e-12, 3.26291491e-12, 3.32077411e-12]])

# %% [markdown]
# When reducing the value of the Courant number, we see that the model becomes unstable for orders higher than 1. But still no similarities between odd and even numbers are apparent.

# %%
fig,axs=plt.subplots(5,1,figsize=[15,20])
afs3.advection3(1250*4, 0,axs[0],lab_example=False) 
afs3.advection3(1250*4, 1,axs[1],lab_example=False)
afs3.advection3(1250*4, 2,axs[2],lab_example=False)
afs3.advection3(1250*4, 3,axs[3],lab_example=False)
afs3.advection3(1250*4, 4,axs[4],lab_example=False)
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [6.89053179e-13, 6.96157715e-13, 7.03330150e-13, ...,
#         7.03330150e-13, 7.10612795e-13, 7.17958161e-13],
#        [6.88351960e-13, 6.95448005e-13, 7.02611786e-13, ...,
#         7.02611786e-13, 7.09885568e-13, 7.17221905e-13],
#        [6.87651572e-13, 6.94739142e-13, 7.01894289e-13, ...,
#         7.01894289e-13, 7.09159227e-13, 7.16486554e-13]])

# %% [markdown]
# b\) For odd ordered polynomials, *advection_funs.py* uses the representation
# of $a_{j,k}$ that involves an extra point to the right of the centre
# grid point. Modify the table of coefficients for odd ordered polynomials
# ([Table $\ell=1$](#tab:ell1))and ([Table $\ell=3$](#tab:ell3)) to use the extra point to the left of the
# centre grid point. Run your program again and compare the results of 2
# different representations of $a_{j,k}$ for order 1 and 3, respectively.
# Is one representation better than the other, or about the same, or does
# each have its own problem? How, do you think the different
# representation affects the result?
#
# -In the figure bellow, order 1 with the original table is shown at the top followed by order 1 with the modified table, order 3 original and order 3 modified. The results for the modified tables are significantly worse, concentration grows in time and does not reach the expected final position after 24 hours. The extra point to the left seems to be unstable in the order 1 and more diffusive in order 3. I do not know how the choose of one scheme against the other would affect higher orders but for 1st and 3rd orders it looks like there is no improvement.

# %%
fig,axs=plt.subplots(4,1,figsize=[15,20])
afs.advection3(1250, 1,axs[0],lab_example=False)
afs2.advection3(1250, 1,axs[1],lab_example=False)
afs.advection3(1250, 3,axs[2],lab_example=False)
afs2.advection3(1250, 3,axs[3],lab_example=False)
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [2.97879623e-12, 3.03089953e-12, 3.08416174e-12, ...,
#         3.08416174e-12, 3.13860903e-12, 3.19426810e-12],
#        [2.95840842e-12, 3.01005839e-12, 3.06285703e-12, ...,
#         3.06285703e-12, 3.11683030e-12, 3.17200466e-12],
#        [2.93819793e-12, 2.98939858e-12, 3.04173775e-12, ...,
#         3.04173775e-12, 3.09524117e-12, 3.14993510e-12]])
